# 117290    682030211896228        18    0.055556   3.777778    1.222222
# 117291    100005824931082         2    0.500000   0.000000    7.000000
# 117292    477163979077807         1    0.000000   0.000000    0.000000
# 117293   1537352853260739         1    0.000000   0.000000    0.000000
# 117294    870805429610494        13    0.076923   0.000000    0.538462
# 117295   1013470395393599         2    0.000000   0.000000  634.500000
# 117296   1036299173122428        16    0.000000   1.250000    1.812500
# 117297  10209267122901007         1    0.000000   0.000000    0.000000
#
#         quests_speed
# 0           1.111111
# 1           0.000000
# 2           0.000000
# 3           4.500000
# 4           0.000000
# 5          11.800000
# 6           2.500000
# 7           0.615385
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          3.000000
# 12          0.000000
# 13          0.000000
# 14          0.504587
# 15          0.000000
# 16          0.137931
# 17          1.200000
# 18          0.000000
# 19          5.000000
# 20          0.000000
# 21          2.250000
# 22          4.500000
# 23          4.000000
# 24          6.000000
# 25          0.000000
# 26          0.000000
# 27          5.714286
# 28          2.666667
# 29          0.000000
# ...              ...
# 117268      0.000000
# 117269      0.000000
# 117270      0.607143
# 117271      0.000000
# 117272      2.111111
# 117273      2.666667
# 117274      0.255319
# 117275      0.000000
# 117276      0.440000
# 117277      1.181818
# 117278      0.000000
# 117279      5.400000
# 117280      0.000000
# 117281      7.000000
# 117282      0.000000
# 117283      0.000000
# 117284      4.800000
# 117285      2.000000
# 117286      0.000000
# 117287      5.500000
# 117288      2.947368
# 117289      9.571429
# 117290      1.388889
# 117291     16.000000
# 117292      0.000000
# 117293      0.000000
# 117294      1.384615
# 117295      1.000000
# 117296      2.062500
# 117297      0.000000
#
# [117298 rows x 6 columns]

# %% [markdown]
# Searching of cluster centers

# %%
# Best number is calculated via cluster1.ipynb
cluster_num = 5
# Search best from 5 random
kmeans = KMeans(n_clusters = cluster_num)
kmeans.fit(df.ix[:,['actcount','med_ml_num','buynum', 'grind','quests_speed']])
best = kmeans
for x in range(5):
    kmeans = KMeans(n_clusters = cluster_num)
    kmeans.fit(df.ix[:,['actcount','med_ml_num','buynum', 'grind','quests_speed']])
    if kmeans.inertia_<best.inertia_:
        best = kmeans
kmeans = best
print "Inertia "+"{:10.4f}".format(kmeans.inertia_)
for x in kmeans.cluster_centers_:
    print '  '.join("{:10.4f}".format(i) for i in x)
with open('cluster_centers.txt','w') as f:
    writer = csv.writer(f, delimiter='|',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['actcount','med_ml_num','buynum', 'grind','quests_speed'])
    for x in kmeans.cluster_centers_:
        writer.writerow(x)
    f.close()
# Out:
# Inertia 107373223.5797
#     4.8303      0.0334      1.1967      1.6982      1.9883
#     4.4211      0.0948     19.8769   1273.2545      6.7070
#    20.7000      0.0902      9.3458    345.0771      5.4622
#    12.0000      0.1353      0.5920   3606.8373      5.6230
#    70.1886      0.0514      8.8869     29.3585      1.0191

# %% [markdown]
# Dividing of users on clusters

# %%
prediction = kmeans.predict(df.ix[:,['actcount','med_ml_num','buynum', 'grind','quests_speed']])
with open('clusters.csv','wb') as f:
    writer = csv.writer(f, delimiter='|',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer.writerow(['id','cluster_index'])
    for i in xrange(len(prediction)):
        writer.writerow([df['id'].ix[i],prediction[i]])
    f.close()
